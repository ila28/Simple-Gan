# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/drive/1wyZ5o8I_T-DKXHENr62rflxLpQuQRfAd#scrollTo=WoTOrF7HeluT)

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)
# Out:
# Mon Feb 22 11:04:41 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.39       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   38C    P0    24W / 300W |      0MiB / 16160MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import numpy as np
import matplotlib.pyplot as plt

from tensorflow import keras
from keras.layers import *
from keras.optimizers import *
from keras import Sequential, Model

# %%
# !gdown --id '1wDoPbO6ZboCYu_MnNabrmFiTgYNSTg_X'
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1wDoPbO6ZboCYu_MnNabrmFiTgYNSTg_X
# To: /content/_____ data.tgz
# 379MB [00:06, 59.8MB/s]

# %%
# !tar -xzf '/content/_____ data.tgz'

# %%
# !mkdir -p /content/anime
# !rm -rf /content/anime/cropped
# !mv /content/cropped /content/anime/

# %%
from tensorflow.keras import *
import numpy as np
import tensorflow as tf
import keras

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(
        rescale=1./255, 
)


train_generator = train_datagen.flow_from_directory(
        r'/content/anime/', 
        target_size=(96, 96),  
        batch_size=64,
        color_mode='rgb',
        # Since we use binary_crossentropy loss, we need binary labels
        class_mode=None,
        # shuffle=False,
        )
# Out:
# Found 63632 images belonging to 1 classes.

# %%
path = '/content/anime/cropped/'

# %%
from tqdm.autonotebook import tqdm
import numpy as np
import pandas as pd
import os
from matplotlib import pyplot as plt
from PIL import Image

PIC_DIR = path
IMAGES_COUNT = 20000
ORIG_WIDTH = 178
ORIG_HEIGHT = 208
diff = (ORIG_HEIGHT - ORIG_WIDTH) // 2
WIDTH = 96
HEIGHT = 96
SIZE = 96, 96
crop_rect = (0, diff, ORIG_WIDTH, ORIG_HEIGHT - diff)
images = []

for pic_file in tqdm(os.listdir(PIC_DIR)[:IMAGES_COUNT]):
    try:
      pic = Image.open(PIC_DIR + pic_file)
      pic.thumbnail(SIZE, Image.ANTIALIAS)
      images.append(np.uint8(pic)) #Normalize the images
    except:
      continue

images = np.array(images) / 255
images.shape #print first 25 images
plt.figure(1, figsize=(10, 10))
for i in range(25):
    plt.subplot(5, 5, i+1)
    plt.imshow(images[i])
    plt.axis('off')
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   """Entry point for launching an IPython kernel.
# HBox(children=(FloatProgress(value=0.0, max=20000.0), HTML(value='')))
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:27: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray

# %%
len(images)
# Out:
# 19987

# %%
LATENT_DIM = 32
CHANNELS = 3
def create_generator():
    gen_input = Input(shape=(LATENT_DIM, ))
    
    x = Dense(128 * 12 * 12)(gen_input)
    x = LeakyReLU()(x)
    x = Reshape((12, 12, 128))(x)
    
    x = Conv2D(256, 5, padding='same')(x)
    x = LeakyReLU()(x)
    
    x = Conv2DTranspose(256, 4, strides=2, padding='same')(x)
    x = LeakyReLU()(x)
    
    x = Conv2DTranspose(256, 4, strides=2, padding='same')(x)
    x = LeakyReLU()(x)
    
    x = Conv2DTranspose(256, 4, strides=2, padding='same')(x)
    x = LeakyReLU()(x)
    
    x = Conv2D(512, 5, padding='same')(x)
    x = LeakyReLU()(x)
    x = Conv2D(512, 5, padding='same')(x)
    x = LeakyReLU()(x)
    x = Conv2D(CHANNELS, 7, activation='tanh', padding='same')(x)
    
    generator = Model(gen_input, x)
    generator.summary()
    return generator

# %%
def create_discriminator():
    disc_input = Input(shape=(96, 96, CHANNELS))
    
    x = Conv2D(256, 3)(disc_input)
    x = LeakyReLU()(x)
    
    x = Conv2D(256, 4, strides=2)(x)
    x = LeakyReLU()(x)
    
    x = Conv2D(256, 4, strides=2)(x)
    x = LeakyReLU()(x)
    
    x = Conv2D(256, 4, strides=2)(x)
    x = LeakyReLU()(x)
    
    x = Conv2D(256, 4, strides=2)(x)
    x = LeakyReLU()(x)
    
    x = Flatten()(x)
    x = Dropout(0.4)(x)
    
    x = Dense(1, activation='sigmoid')(x)
    discriminator = Model(disc_input, x)
    
    optimizer = RMSprop(
        lr=.0001,
        clipvalue=1.0,
        decay=1e-8
    )
    
    discriminator.compile(
        optimizer=optimizer,
        loss='binary_crossentropy'
    )
    
    return discriminator

# %%
generator = create_generator()
discriminator = create_discriminator()
discriminator.trainable = False
gan_input = Input(shape=(LATENT_DIM, ))
gan_output = discriminator(generator(gan_input))
gan = Model(gan_input, gan_output)
optimizer = RMSprop(lr=.0001, clipvalue=1.0, decay=1e-8)
gan.compile(optimizer=optimizer, loss='binary_crossentropy')
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32)]              0
# _________________________________________________________________
# dense (Dense)                (None, 18432)             608256
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 18432)             0
# _________________________________________________________________
# reshape (Reshape)            (None, 12, 12, 128)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 12, 12, 256)       819456
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 12, 12, 256)       0
# _________________________________________________________________
# conv2d_transpose (Conv2DTran (None, 24, 24, 256)       1048832
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 24, 24, 256)       0
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 48, 48, 256)       1048832
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 48, 48, 256)       0
# _________________________________________________________________
# conv2d_transpose_2 (Conv2DTr (None, 96, 96, 256)       1048832
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 96, 96, 256)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 96, 96, 512)       3277312
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 96, 96, 512)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 96, 96, 512)       6554112
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 96, 96, 512)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 96, 96, 3)         75267
# =================================================================
# Total params: 14,480,899
# Trainable params: 14,480,899
# Non-trainable params: 0
# _________________________________________________________________

# %%
images_reshaped = []
for im in images:
  if im.shape == (96, 96, 3):
    images_reshaped.append(im)

images_reshaped = np.array(images_reshaped)
images_reshaped.shape
# Out:
# (7764, 96, 96, 3)

# %%
import time
iters = 3000
batch_size = 2

RES_DIR = 'res2'
FILE_PATH = '%s/generated_%d.png'
if not os.path.isdir(RES_DIR):
    os.mkdir(RES_DIR)

CONTROL_SIZE_SQRT = 6
control_vectors = np.random.normal(size=(CONTROL_SIZE_SQRT**2, LATENT_DIM)) / 2

start = 0
d_losses = []
a_losses = []
images_saved = 0
for step in tqdm(range(iters)):
    start_time = time.time()
    latent_vectors = np.random.normal(size=(batch_size, LATENT_DIM))
    generated = generator.predict(latent_vectors)

    real = images_reshaped[start:start + batch_size]
    combined_images = np.concatenate([generated, real])

    labels = np.concatenate([np.ones((batch_size, 1)), np.zeros((batch_size, 1))])
    labels += .05 * np.random.random(labels.shape)

    d_loss = discriminator.train_on_batch(combined_images, labels)
    d_losses.append(d_loss)

    latent_vectors = np.random.normal(size=(batch_size, LATENT_DIM))
    misleading_targets = np.zeros((batch_size, 1))

    a_loss = gan.train_on_batch(latent_vectors, misleading_targets)
    a_losses.append(a_loss)

    start += batch_size
    if start > images_reshaped.shape[0] - batch_size:
        start = 0

    if step % 100 == 99:
        # gan.save_weights('./drive/My Drive/gan.h5')

        print('%d/%d: d_loss: %.4f,  a_loss: %.4f.  (%.1f sec)' % (step + 1, iters, d_loss, a_loss, time.time() - start_time))

        control_image = np.zeros((WIDTH * CONTROL_SIZE_SQRT, HEIGHT * CONTROL_SIZE_SQRT, CHANNELS))
        control_generated = generator.predict(control_vectors)
        for i in range(CONTROL_SIZE_SQRT ** 2):
            x_off = i % CONTROL_SIZE_SQRT
            y_off = i // CONTROL_SIZE_SQRT
            control_image[x_off * WIDTH:(x_off + 1) * WIDTH, y_off * HEIGHT:(y_off + 1) * HEIGHT, :] = control_generated[i, :, :, :]
        im = Image.fromarray(np.uint8(control_image * 255))
        im.save(FILE_PATH % (RES_DIR, images_saved))
        images_saved += 1


plt.figure(1, figsize=(12, 8))
plt.subplot(121)
plt.plot(d_losses)
plt.xlabel('epochs')
plt.ylabel('discriminant losses')
plt.subplot(122)
plt.plot(a_losses)
plt.xlabel('epochs')
plt.ylabel('adversary losses')
plt.show()

import imageio
import shutil

images_to_gif = []
for filename in os.listdir(RES_DIR):
    images_to_gif.append(imageio.imread(RES_DIR + '/' + filename))
imageio.mimsave('visual.gif', images_to_gif)
shutil.rmtree(RES_DIR)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=3000.0), HTML(value='')))
# 100/3000: d_loss: 0.6395,  a_loss: 1.6799.  (0.2 sec)
# 200/3000: d_loss: 0.4801,  a_loss: 1.0340.  (0.2 sec)
# 300/3000: d_loss: 0.6059,  a_loss: 0.7927.  (0.2 sec)
# 400/3000: d_loss: 0.6891,  a_loss: 1.2118.  (0.2 sec)
# 500/3000: d_loss: 0.9310,  a_loss: 1.4905.  (0.2 sec)
# 600/3000: d_loss: 0.7952,  a_loss: 2.4582.  (0.2 sec)
# 700/3000: d_loss: 0.5788,  a_loss: 1.8896.  (0.2 sec)
# 800/3000: d_loss: 0.7256,  a_loss: 1.5764.  (0.2 sec)
# 900/3000: d_loss: 0.2904,  a_loss: 1.8733.  (0.2 sec)
# 1000/3000: d_loss: 0.4871,  a_loss: 0.8746.  (0.2 sec)
# 1100/3000: d_loss: 0.3974,  a_loss: 1.5312.  (0.2 sec)
# 1200/3000: d_loss: 0.5531,  a_loss: 1.8645.  (0.2 sec)
# 1300/3000: d_loss: 0.4046,  a_loss: 1.9794.  (0.2 sec)
# 1400/3000: d_loss: 0.6237,  a_loss: 0.9538.  (0.2 sec)
# 1500/3000: d_loss: 0.6786,  a_loss: 1.1406.  (0.2 sec)
# 1600/3000: d_loss: 0.4660,  a_loss: 1.5986.  (0.2 sec)
# 1700/3000: d_loss: 0.9289,  a_loss: 1.8217.  (0.2 sec)
# 1800/3000: d_loss: 0.5811,  a_loss: 1.1451.  (0.2 sec)
# 1900/3000: d_loss: 0.4401,  a_loss: 1.3093.  (0.2 sec)
# 2000/3000: d_loss: 0.7130,  a_loss: 2.4839.  (0.2 sec)
# 2100/3000: d_loss: 0.6497,  a_loss: 0.6411.  (0.2 sec)
# 2200/3000: d_loss: 0.6466,  a_loss: 2.0341.  (0.2 sec)
# 2300/3000: d_loss: 0.7005,  a_loss: 1.2129.  (0.2 sec)
# 2400/3000: d_loss: 0.4467,  a_loss: 1.5305.  (0.2 sec)
# 2500/3000: d_loss: 0.3416,  a_loss: 1.1819.  (0.2 sec)
# 2600/3000: d_loss: 0.3851,  a_loss: 1.8441.  (0.2 sec)
# 2700/3000: d_loss: 0.7228,  a_loss: 1.3537.  (0.2 sec)
# 2800/3000: d_loss: 0.5972,  a_loss: 1.7013.  (0.2 sec)
# 2900/3000: d_loss: 0.4730,  a_loss: 1.0648.  (0.2 sec)
# 3000/3000: d_loss: 0.7048,  a_loss: 1.5162.  (0.2 sec)
